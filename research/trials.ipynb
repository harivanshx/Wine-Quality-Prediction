# %%
import os

# %%
#python config box

d = {"key1" : "value1", "key2": "value2"}

# %%
d["key1"]
# Out:
# 'value1'

# %%
d.values
# Out:
# <function dict.values()>

# %%
d.items()
# Out:
# dict_items([('key1', 'value1'), ('key2', 'value2')])

# %%
d['key2']
# Out:
# 'value2'

# %%
# d.key1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 d.key1
#
# AttributeError: 'dict' object has no attribute 'key1'

# %%
from box import ConfigBox

# %%
d2 = ConfigBox({"key1" : "value1", "key2": "value2"})

# %%
d.keys
# Out:
# <function dict.keys()>

# %%
d2.key1
# Out:
# 'value1'

# %%
d2.key2
# Out:
# 'value2'

# %%
def get_product(x:int, y:int) -> int:
    return x * y

# %%
get_product(3,4)
# Out:
# 12

# %%
get_product("3",3)
# Out:
# '333'

# %%
# !pip install ensure
# Out:
# Requirement already satisfied: ensure in c:\users\hariv\anaconda3\envs\mlproj\lib\site-packages (1.0.2)
# Requirement already satisfied: six>=1.11.0 in c:\users\hariv\anaconda3\envs\mlproj\lib\site-packages (from ensure) (1.17.0)

# %%
pip install typeguard
# Out:
# Collecting typeguard
#   Using cached typeguard-4.4.4-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: typing_extensions>=4.14.0 in c:\users\hariv\anaconda3\envs\mlproj\lib\site-packages (from typeguard) (4.15.0)
# Using cached typeguard-4.4.4-py3-none-any.whl (34 kB)
# Installing collected packages: typeguard
# Successfully installed typeguard-4.4.4
# Note: you may need to restart the kernel to use updated packages.

# %%
def get_product(x:int, y:int) -> int:
   
    return x * y

# %%
get_product(3,4)
# Out:
# 12
